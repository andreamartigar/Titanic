# %% [markdown]
# # Introducción
#
# Vamos a analizar un conjunto de datos de canciones y sus estadísticas por semanas: `listas_musica.csv`
#
# Es un conjunto de datos que nos permite trabajar los conceptos de `pandas` y `numpy`.
#
# El ejercicio será guiado aunque se permite no ver las soluciones para realizar las tareas.
#
# Las columnas del `dataset` son:
#
# * `date`:	Tipo `date` - Fecha de la lista.
# * `rank`:	Tipo `int`	- Posición del ranking de la canción en esa fecha.
# * `song`:	Tipo `str`	- Nombre de la canción.
# * `artist`:	Tipo `str` - Artista.
# * `last-week`:	Tipo `int` -	Posición en el ranking de la semana anterior.
# * `peak-rank`: Tipo `int`	- La mejor posición de la canción en el ranking.
# * `weeks-on-board`: Tipo `int` -	Número de semanas que la canción lleva en la lista.

# %% [markdown]
# # Carga de librerías
#
# Cargue las librerías `numpy`, `pandas` y `os`.

# %% [markdown]
# ### Solución

# %%
import numpy as np
import pandas as pd
import os

# %% [markdown]
# # Carga del dataset
#
# Lea el dataset y conviértalo en un `dataframe`.
#
# Imprima el dataset una vez lo tenga.

# %% [markdown]
# ### Solución

# %%
#Ruta del archivo
ruta_archivo = 'C:/Users/Andrea/Desktop/BOOTCAMP/Bootcamp/modulo I/13. Ejercicios proyecto módulo I/listas_musica.csv'

# %%
os.path.exists('C:/Users/Andrea/Desktop/BOOTCAMP/Bootcamp/modulo I/13. Ejercicios proyecto módulo I/listas_musica.csv')
dataframe = pd.read_csv('C:/Users/Andrea/Desktop/BOOTCAMP/Bootcamp/modulo I/13. Ejercicios proyecto módulo I/listas_musica.csv')

# %%
dataframe.head()
# Out:
#          date  rank           song                         artist  last-week  \
# 0  2021-11-06     1     Easy On Me                          Adele        1.0
# 1  2021-11-06     2           Stay  The Kid LAROI & Justin Bieber        2.0
# 2  2021-11-06     3  Industry Baby        Lil Nas X & Jack Harlow        3.0
# 3  2021-11-06     4     Fancy Like                   Walker Hayes        4.0
# 4  2021-11-06     5     Bad Habits                     Ed Sheeran        5.0
#
#    peak-rank  weeks-on-board
# 0          1               3
# 1          1              16
# 2          1              14
# 3          3              19
# 4          2              18

# %% [markdown]
# #Limpieza de datos
#
# Rellene con `0` usando `fillna()`.

# %% [markdown]
# ### Solución

# %%
#Buscamos si hay objetos nulos
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330087 entries, 0 to 330086
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date            330087 non-null  object
#  1   rank            330087 non-null  int64
#  2   song            330087 non-null  object
#  3   artist          330087 non-null  object
#  4   last-week       297775 non-null  float64
#  5   peak-rank       330087 non-null  int64
#  6   weeks-on-board  330087 non-null  int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 17.6+ MB

# %%
dataframe["last-week"]
# Out:
# 0         1.0
# 1         2.0
# 2         3.0
# 3         4.0
# 4         5.0
#          ...
# 330082    NaN
# 330083    NaN
# 330084    NaN
# 330085    NaN
# 330086    NaN
# Name: last-week, Length: 330087, dtype: float64

# %% [markdown]
# No podremos hacer promedios de la columna last-week después de rellenar los nulos con 0

# %%
dataframe = dataframe.fillna(0)

# %%
dataframe.fillna(0, inplace = True)

# %%
dataframe.head(30)
# Out:
#           date  rank                            song  \
# 0   2021-11-06     1                      Easy On Me
# 1   2021-11-06     2                            Stay
# 2   2021-11-06     3                   Industry Baby
# 3   2021-11-06     4                      Fancy Like
# 4   2021-11-06     5                      Bad Habits
# 5   2021-11-06     6                      Way 2 Sexy
# 6   2021-11-06     7                         Shivers
# 7   2021-11-06     8                        Good 4 U
# 8   2021-11-06     9                    Need To Know
# 9   2021-11-06    10                      Levitating
# 10  2021-11-06    11                         Essence
# 11  2021-11-06    12                    Kiss Me More
# 12  2021-11-06    13                      Heat Waves
# 13  2021-11-06    14                         Beggin'
# 14  2021-11-06    15         Cold Heart (PNAU Remix)
# 15  2021-11-06    16                       You Right
# 16  2021-11-06    17                 Save Your Tears
# ...

# %% [markdown]
# # Imprima algunos valores de ejemplos
#
# Use `tail()` para imprimir algunos valores.
#
# Fíjese en las columnas del dataset.

# %% [markdown]
# ### Solución

# %%
dataframe.tail()
# Out:
#               date  rank                                 song  \
# 330082  1958-08-04    96                        Over And Over
# 330083  1958-08-04    97                     I Believe In You
# 330084  1958-08-04    98                      Little Serenade
# 330085  1958-08-04    99  I'll Get By (As Long As I Have You)
# 330086  1958-08-04   100                                 Judy
#
#                    artist  last-week  peak-rank  weeks-on-board
# 330082    Thurston Harris        0.0         96               1
# 330083    Robert & Johnny        0.0         97               1
# 330084  The Ames Brothers        0.0         98               1
# 330085     Billy Williams        0.0         99               1
# 330086    Frankie Vaughan        0.0        100               1

# %% [markdown]
# # Calcule los top 30 artistas
#
# Puede usar la función `value_counts()` y `head(...)`.
#
# Fíjese en usar la columna correspondiente.

# %% [markdown]
# ### Solución

# %%
dataframe["artist"]
# Out:
# 0                                 Adele
# 1         The Kid LAROI & Justin Bieber
# 2               Lil Nas X & Jack Harlow
# 3                          Walker Hayes
# 4                            Ed Sheeran
#                       ...
# 330082                  Thurston Harris
# 330083                  Robert & Johnny
# 330084                The Ames Brothers
# 330085                   Billy Williams
# 330086                  Frankie Vaughan
# Name: artist, Length: 330087, dtype: object

# %%
top_30_artistas = dataframe['artist'].value_counts().head(30)
print(top_30_artistas)
# Out:
# artist
# Taylor Swift             1023
# Elton John                889
# Madonna                   857
# Drake                     787
# Kenny Chesney             769
# Tim McGraw                731
# Keith Urban               673
# Stevie Wonder             659
# Rod Stewart               657
# Mariah Carey              621
# Michael Jackson           611
# Chicago                   607
# Rascal Flatts             604
# Billy Joel                588
# The Rolling Stones        585
# The Beatles               585
# Jason Aldean              572
# Aretha Franklin           569
# Rihanna                   566
# P!nk                      564
# Whitney Houston           561
# Brad Paisley              559
# Neil Diamond              553
# George Strait             553
# Luke Bryan                543
# Carrie Underwood          541
# Daryl Hall John Oates     540
# The Beach Boys            531
# Toby Keith                526
# Bee Gees                  516
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# Assuming 'dataframe' is your pandas DataFrame containing the 'artist' column
top_30_artistas = dataframe['artist'].value_counts().head(30)

# Plotting the bar chart
plt.figure(figsize=(10, 6))
top_30_artistas.plot(kind='bar', color='skyblue')
plt.title('Top 30 Artists')
plt.xlabel('Artists')
plt.ylabel('Number of Songs')
plt.xticks(rotation=45, ha='right')  
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# # Muestre el top 15 de canciones junto con su cantante

# %% [markdown]
# ### Solución

# %%
top_15_canciones = dataframe[['artist','song']].value_counts().head(15)

pd.DataFrame(top_15_canciones)
# Out:
#                                                                                count
# artist                                    song
# The Weeknd                                Blinding Lights                         90
# Imagine Dragons                           Radioactive                             87
# AWOLNATION                                Sail                                    79
# Jason Mraz                                I'm Yours                               76
# LeAnn Rimes                               How Do I Live                           69
# LMFAO Featuring Lauren Bennett & GoonRock Party Rock Anthem                       68
# OneRepublic                               Counting Stars                          68
# Jewel                                     Foolish Games/You Were Meant For Me     65
# Adele                                     Rolling In The Deep                     65
# ...

# %%
# Plotting the bar chart using Plotly Express

import plotly.express as px
fig = px.bar(top_15_canciones_df, x='song', y='count', color='artist',
             labels={'Count': 'Number of Songs', 'song': 'Song'},
             title='Top 15 Songs by Artist',
             width=800, height=500)

# Customize layout if needed
fig.update_layout(xaxis_title='Song', yaxis_title='Number of Songs')

# Show the plot
fig.show()

# %% [markdown]
# ### Solución

# %%
total_semanas = df.groupby(['artist', 'song'])['weeks-on-board'].max().reset_index()

top_15 = total_semanas.sort_values(by='weeks-on-board', ascending=False).head(15)

top_15
# Out:
#                                           artist  \
# 27367                                 The Weeknd
# 11281                            Imagine Dragons
# 405                                   AWOLNATION
# 12119                                 Jason Mraz
# 15133                                LeAnn Rimes
# 14933  LMFAO Featuring Lauren Bennett & GoonRock
# 18958                                OneRepublic
# 510                                        Adele
# 12514                                      Jewel
# 4375                            Carrie Underwood
# 15350                                  Lifehouse
# 25910                              The Lumineers
# 9585        Gabby Barrett Featuring Charlie Puth
# 20083                                Post Malone
# 11274                            Imagine Dragons
#
#                                       song  weeks-on-board
# 27367                      Blinding Lights              90
# ...

# %% [markdown]
# #Muestre el top 10 de los artistas, canciones y su mejor posición

# %%
print(dataframe[["artist", "song", "peak-rank"]].value_counts().head(10))
# Out:
# artist                                     song                     peak-rank
# The Weeknd                                 Blinding Lights          1            74
# Ed Sheeran                                 Shape Of You             1            58
# Jason Mraz                                 I'm Yours                6            56
# LMFAO Featuring Lauren Bennett & GoonRock  Party Rock Anthem        1            54
# The Black Eyed Peas                        I Gotta Feeling          1            54
# Justin Timberlake                          Can't Stop The Feeling!  1            52
# Taylor Swift                               Shake It Off             1            50
# The Chainsmokers Featuring Halsey          Closer                   1            50
# Post Malone                                Circles                  1            50
# Mark Ronson Featuring Bruno Mars           Uptown Funk!             1            49
# Name: count, dtype: int64

# %%
top_canciones = dataframe.groupby(['song', 'artist'])['peak-rank'].min().sort_values().head(10)

# %% [markdown]
# # Artistas más reproducidos por semanas
#
# Transforme la columna `date` en `datetime`.
#
# Use  `set_index` para crear un índice en la columna `date`.
#
# Imprima el dataframe con el nuevo índice.

# %% [markdown]
# ### Solución

# %%
dataframe['date'] = pd.to_datetime(dataframe['date'])

# %%
dataframe['date'] = dataframe['date'].apply(pd.to_datetime)
# apply sirve para todo tipo de funciones

# %%
dataframe.set_index('date', inplace=True)
dataframe.head()
# Out:
#             rank           song                         artist  last-week  \
# date
# 2021-11-06     1     Easy On Me                          Adele        1.0
# 2021-11-06     2           Stay  The Kid LAROI & Justin Bieber        2.0
# 2021-11-06     3  Industry Baby        Lil Nas X & Jack Harlow        3.0
# 2021-11-06     4     Fancy Like                   Walker Hayes        4.0
# 2021-11-06     5     Bad Habits                     Ed Sheeran        5.0
#
#             peak-rank  weeks-on-board
# date
# 2021-11-06          1               3
# 2021-11-06          1              16
# 2021-11-06          1              14
# 2021-11-06          3              19
# 2021-11-06          2              18

# %%
dataframe[dataframe["rank"] == 1]
# Out:
#             rank                             song  \
# date
# 2021-11-06     1                       Easy On Me
# 2021-10-30     1                       Easy On Me
# 2021-10-23     1                    Industry Baby
# 2021-10-16     1                             Stay
# 2021-10-09     1                      My Universe
# ...          ...                              ...
# 1958-09-01     1  Nel Blu Dipinto Di Blu (Volaré)
# 1958-08-25     1                      Little Star
# 1958-08-18     1  Nel Blu Dipinto Di Blu (Volaré)
# 1958-08-11     1                 Poor Little Fool
# 1958-08-04     1                 Poor Little Fool
#
#                                    artist  last-week  peak-rank  \
# date
# 2021-11-06                          Adele        1.0          1
# 2021-10-30                          Adele       68.0          1
# 2021-10-23        Lil Nas X & Jack Harlow        2.0          1
# 2021-10-16  The Kid LAROI & Justin Bieber        2.0          1
# ...

# %%
dataframe.shape
# Out:
# (330087, 6)

# %% [markdown]
# # Encuentre los más y menos escuchados según un intervalo de tiempo
#
# Puede usar `resample(frecuencia)[columna]`.
#
# Las frecuencias que puede usar son:
# * H - Horaria
# * D - Diaria
# * W - Semanal
# * M - Mensual
# * A - Anual
#
# Puede usar `.agg([columnas])` para agregar los datos

# %% [markdown]
# ### Solución

# %%
dataframe.head(100)
# Out:
#             rank                song                         artist  \
# date
# 2021-11-06     1          Easy On Me                          Adele
# 2021-11-06     2                Stay  The Kid LAROI & Justin Bieber
# 2021-11-06     3       Industry Baby        Lil Nas X & Jack Harlow
# 2021-11-06     4          Fancy Like                   Walker Hayes
# 2021-11-06     5          Bad Habits                     Ed Sheeran
# ...          ...                 ...                            ...
# 2021-11-06    96  To Be Loved By You                Parker McCollum
# 2021-11-06    97          Ain't Shit                       Doja Cat
# 2021-11-06    98        Life Goes On                    Oliver Tree
# 2021-11-06    99        Come Through   H.E.R. Featuring Chris Brown
# 2021-11-06   100              Nevada     YoungBoy Never Broke Again
#
#             last-week  peak-rank  weeks-on-board
# date
# 2021-11-06        1.0          1               3
# ...

# %%
# Semanal
dataframe.resample('W')['artist']

# %%
dataframe.resample('W')['artist'].agg(["first","last"])
# Out:
#                                     first                        last
# date
# 1958-08-10                   Ricky Nelson             Frankie Vaughan
# 1958-08-17                   Ricky Nelson        The Kirby Stone Four
# 1958-08-24               Domenico Modugno     Count Basie & His Orch.
# 1958-08-31                   The Elegants              Eileen Rodgers
# 1958-09-07               Domenico Modugno                  Jill Corey
# ...                                   ...                         ...
# 2021-10-10                 Coldplay x BTS                  Kanye West
# 2021-10-17  The Kid LAROI & Justin Bieber  YoungBoy Never Broke Again
# 2021-10-24        Lil Nas X & Jack Harlow  YoungBoy Never Broke Again
# 2021-10-31                          Adele             Priscilla Block
# 2021-11-07                          Adele  YoungBoy Never Broke Again
#
# [3301 rows x 2 columns]

# %%
#Anual
dataframe.resample('Y')['artist'].agg(["first","last"])
# Out:
#                                          first  \
# date
# 1958-12-31                        Ricky Nelson
# 1959-12-31    The Chipmunks With David Seville
# 1960-12-31                       Marty Robbins
# 1961-12-31  Elvis Presley With The Jordanaires
# 1962-12-31                          The Tokens
# ...                                        ...
# 2017-12-31      The Weeknd Featuring Daft Punk
# 2018-12-31                          Ed Sheeran
# 2019-12-31                       Ariana Grande
# 2020-12-31                        Mariah Carey
# 2021-12-31                        Mariah Carey
#
#                                                      last
# date
# 1958-12-31                              The Ames Brothers
# 1959-12-31                                  The Knockouts
# 1960-12-31                                  Etta & Harvey
# 1961-12-31                                Jimmie Beaumont
# 1962-12-31                                      Don Covay
# ...

# %%
dataframe_new = dataframe['artist'].resample('A').agg({'mejor_artista': lambda x: x.mode().iloc[0], 'peor artista': lambda x: x.value_counts().idxmin()})

# %%
dataframe_new
# Out:
#                   mejor_artista  \
# date
# 1958-12-31  The Everly Brothers
# 1959-12-31          Fats Domino
# 1960-12-31       Connie Francis
# 1961-12-31       Connie Francis
# 1962-12-31           Brenda Lee
# ...                         ...
# 2017-12-31           Ed Sheeran
# 2018-12-31                Drake
# 2019-12-31        Billie Eilish
# 2020-12-31           The Weeknd
# 2021-12-31       Olivia Rodrigo
#
#                                                  peor artista
# date
# 1958-12-31                 Huey "piano" Smith With His Clowns
# 1959-12-31                                         Jim Reeves
# 1960-12-31  The Drifters Featuring Clyde McPhatter And Bil...
# 1961-12-31                                         Tina Robin
# 1962-12-31                                         The Rebels
# ...                                                       ...
# 2017-12-31                                 Migos & Marshmello
# ...

# %%
#Lo hacemos por semana
dataframe.resample('W')['artist']

# %%
dataframe.resample('W')['artist'].agg(["first", "last"])
# Out:
#                                     first                        last
# date
# 1958-08-10                   Ricky Nelson             Frankie Vaughan
# 1958-08-17                   Ricky Nelson        The Kirby Stone Four
# 1958-08-24               Domenico Modugno     Count Basie & His Orch.
# 1958-08-31                   The Elegants              Eileen Rodgers
# 1958-09-07               Domenico Modugno                  Jill Corey
# ...                                   ...                         ...
# 2021-10-10                 Coldplay x BTS                  Kanye West
# 2021-10-17  The Kid LAROI & Justin Bieber  YoungBoy Never Broke Again
# 2021-10-24        Lil Nas X & Jack Harlow  YoungBoy Never Broke Again
# 2021-10-31                          Adele             Priscilla Block
# 2021-11-07                          Adele  YoungBoy Never Broke Again
#
# [3301 rows x 2 columns]

# %%
#Lo hacemos por Año
dataframe.resample('Y')['artist']

# %%
dataframe.resample('Y')['artist'].agg(["first", "last"])
# Out:
#                                          first  \
# date
# 1958-12-31                        Ricky Nelson
# 1959-12-31    The Chipmunks With David Seville
# 1960-12-31                       Marty Robbins
# 1961-12-31  Elvis Presley With The Jordanaires
# 1962-12-31                          The Tokens
# ...                                        ...
# 2017-12-31      The Weeknd Featuring Daft Punk
# 2018-12-31                          Ed Sheeran
# 2019-12-31                       Ariana Grande
# 2020-12-31                        Mariah Carey
# 2021-12-31                        Mariah Carey
#
#                                                      last
# date
# 1958-12-31                              The Ames Brothers
# 1959-12-31                                  The Knockouts
# 1960-12-31                                  Etta & Harvey
# 1961-12-31                                Jimmie Beaumont
# 1962-12-31                                      Don Covay
# ...

# %%
# Para hacerlo por año
dataframe[dataframe.index.year == 2020]
# Out:
#             rank                               song  \
# date
# 2020-12-26     1                             Willow
# 2020-12-26     2    All I Want For Christmas Is You
# 2020-12-26     3  Rockin' Around The Christmas Tree
# 2020-12-26     4                   Jingle Bell Rock
# 2020-12-26     5                               Mood
# ...          ...                                ...
# 2020-01-04    96                              Candy
# 2020-01-04    97                      BEST ON EARTH
# 2020-01-04    98                               Tusa
# 2020-01-04    99                            Enemies
# 2020-01-04   100                South Of The Border
#
#                                                    artist  last-week  \
# date
# 2020-12-26                                   Taylor Swift        0.0
# 2020-12-26                                   Mariah Carey        1.0
# 2020-12-26                                     Brenda Lee        3.0
# ...
